# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.ensemble import IsolationForest
from sklearn.inspection import DecisionBoundaryDisplay

# %%
X, y = make_blobs(n_samples=500, cluster_std=0.5, centers=1, random_state=42)
plt.scatter(X[:, 0], X[:, 1])
plt.xlim([-8, 2])
plt.ylim([5, 15])
plt.grid()
plt.tight_layout(pad=0)
plt.show()

# %%
clf = IsolationForest()
clf.fit(X)
disp = DecisionBoundaryDisplay.from_estimator(
    clf,
    X,
    response_method='decision_function',
    alpha=0.5)
plt.gca().set_axis_off()
plt.show()

# %%
X, y = make_blobs(n_samples=500, cluster_std=0.5, centers=2, random_state=42)
plt.scatter(X[:, 0], X[:, 1])
plt.grid()
plt.tight_layout(pad=0)
plt.savefig('two_clusters.png', dpi=600)
plt.show()

# %%
clf = IsolationForest()
clf.fit(X)
disp = DecisionBoundaryDisplay.from_estimator(
    clf,
    X,
    response_method='decision_function',
    alpha=0.5)
plt.gca().set_axis_off()
plt.show()
