# %%
from ultralytics import YOLO

# %%
model_seg = YOLO('yolov8n-seg.pt')
model_seg.train(data='coco128-seg.yaml', epochs=3, imgsz=75)
# Out:
# Ultralytics YOLOv8.0.111  Python-3.10.11 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 4090 Laptop GPU, 16376MiB)
# ...

# %%
results = model_seg.predict('https://ultralytics.com/images/bus.jpg', save=True)
# Out:
# ...
# 100%|██████████| 476k/476k [00:00<00:00, 1.18MB/s]
# image 1/1 C:\Users\acard\Documents\Lavoro\Corsi\pcs-exercises\03_dl\04_yolo\bus.jpg: 96x96 2 persons, 1 car, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 4.0ms postprocess per image at shape (1, 3, 96, 96)
# Results saved to runs\segment\predict
